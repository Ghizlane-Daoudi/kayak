# %% [markdown]
# # Project : Plan your trip with KAYAK

# %%
# Importing useful libraries

import pandas as pd
import requests
import json
import pprint
from datetime import datetime

# !pip install plotly -q
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
pio.renderers.default = "iframe_connected"

# !pip install scrapy -q
import scrapy
import os
import logging
from scrapy.crawler import CrawlerProcess

# %% [markdown]
# ## Part I : Get coordinates of cities from nominatim.org's API

# %%
# Define the list of cities we are interested in

cities = ["Mont Saint Michel",
"St Malo",
"Bayeux",
"Le Havre",
"Rouen",
"Paris",
"Amiens",
"Lille",
"Strasbourg",
"Chateau du Haut Koenigsbourg",
"Colmar",
"Eguisheim",
"Besancon",
"Dijon",
"Annecy",
"Grenoble",
"Lyon",
"Gorges du Verdon",
"Bormes les Mimosas",
"Cassis",
"Marseille",
"Aix en Provence",
"Avignon",
"Uzes",
"Nimes",
"Aigues Mortes",
"Saintes Maries de la mer",
"Collioure",
"Carcassonne",
"Ariege",
"Toulouse",
"Montauban",
"Biarritz",
"Bayonne",
"La Rochelle"]

# %%
# Store the cities in a dataframe
df=pd.DataFrame(cities, columns=['city'])
df.head()
# Out:
#                 city
# 0  Mont Saint Michel
# 1            St Malo
# 2             Bayeux
# 3           Le Havre
# 4              Rouen

# %%
# Use the requests library to get geolocalisation data from openstreetmap API
# example of France
r = requests.get('https://nominatim.openstreetmap.org/search?country=France&format=json')
resultat = r.json()
resultat
# Out:
# [{'place_id': 282341688,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 2202162,
#   'boundingbox': ['-50.2187169', '51.3055721', '-178.3873749', '172.3057152'],
#   'lat': '46.603354',
#   'lon': '1.8883335',
#   'display_name': 'France',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 1.0233264437396503,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png'}]

# %%
print('France latitude is: ' ,resultat[0].get('lat'))
print('France longitude is: ' ,resultat[0].get('lon'))
# Out:
# France latitude is:  46.603354
# France longitude is:  1.8883335

# %%
# Define a function that gets the coordinates of one city
def city_coordinates(city):
    try:
        encoded_city = city.replace(' ','+') # to handle the query
        r = requests.get('https://nominatim.openstreetmap.org/search?q={}&country=France&format=json'.format(encoded_city))
        resultat = r.json()
        lat = resultat[0].get('lat')
        lon = resultat[0].get('lon')
        return (lat, lon)
    except IndexError:
        return (None, None)

# %%
# Test on a city that not exists
a = city_coordinates('lkkhkjh kjhkh kjhkj ')
a
# Out:
# (None, None)

# %%
b = city_coordinates('Rouen')
b
# Out:
# ('49.4404591', '1.0939658')

# %% [markdown]
# As coordinates are strings we will transform them to floats in the following

# %%
# Create columns where cities coordinates will be stored
df['latitude'] = None
df['longitude'] = None

# Iterate on all cities
for i in df.index:
    df['latitude'][i]= round(float(city_coordinates(df['city'][i])[0]),4) # the function returns a tuple of (lat, lon). In the position 0 we get latitude
    df['longitude'][i]= round(float(city_coordinates(df['city'][i])[1]),4) # the function returns a tuple of (lat, lon). In the position 0 we get latitude

# %%
# Show the dataset
df
# Out:
#                             city latitude longitude
# 0              Mont Saint Michel   48.636   -1.5115
# 1                        St Malo  48.6495    -2.026
# 2                         Bayeux  49.2765   -0.7025
# 3                       Le Havre  49.4939     0.108
# 4                          Rouen  49.4405     1.094
# 5                          Paris  48.8589      2.32
# 6                         Amiens  49.8942    2.2957
# 7                          Lille  50.6366    3.0635
# 8                     Strasbourg  48.5846    7.7507
# 9   Chateau du Haut Koenigsbourg  48.2495    7.3443
# 10                        Colmar  48.0778     7.358
# 11                     Eguisheim  48.0448     7.308
# 12                      Besancon   47.238    6.0244
# 13                         Dijon  47.3216    5.0415
# 14                        Annecy  45.8992    6.1289
# 15                      Grenoble  45.1876    5.7358
# 16                          Lyon  45.7578     4.832
# 17              Gorges du Verdon  43.7497    6.3286
# 18            Bormes les Mimosas  43.1572    6.3293
# 19                        Cassis   43.214    5.5396
# 20                     Marseille  43.2962      5.37
# 21               Aix en Provence  43.5298    5.4475
# 22                       Avignon  43.9492    4.8059
# 23                          Uzes  44.0121    4.4197
# 24                         Nimes  43.8374    4.3601
# 25                 Aigues Mortes  43.5658    4.1913
# 26      Saintes Maries de la mer  43.4523    4.4287
# 27                     Collioure  42.5251    3.0832
# 28                   Carcassonne   43.213    2.3491
# 29                        Ariege  42.9455    1.4066
# 30                      Toulouse  43.6045    1.4442
# 31                     Montauban  44.0176     1.355
# 32                      Biarritz  43.4711   -1.5527
# 33                       Bayonne  43.4933   -1.4751
# 34                   La Rochelle  46.1591    -1.152

# %%
df.to_csv('src/cities_coordinates.csv')

# %% [markdown]
# ## Part II : Get weather data from openweathermap API

# %%
# Use requests Library to get weather data from openweathermal API
# Example to have a look to the content of the response
example_coord = [df.latitude[0],df.longitude[0]]
example_weather = requests.get(
    "https://api.openweathermap.org/data/2.5/onecall?lat={}&lon={}&exclude=hourly,current,minutely&appid=93dd497abfa8c0ecdc1920ba1bacd20e4&units=metric"
    .format(example_coord[0],example_coord[1]))
example_weather
# Out:
# <Response [200]>

# %%
# Look to the content of the response. We will use the pretty printer module of python to display the content in a clearer format
example_weather = example_weather.json()
pprint.pprint(example_weather)
# Out:
# {'daily': [{'clouds': 89,
#             'dew_point': 7.23,
#             'dt': 1643284800,
#             'feels_like': {'day': 9.73,
#                            'eve': 6.71,
#                            'morn': -1.04,
#                            'night': 8.49},
#             'humidity': 80,
#             'moon_phase': 0.82,
#             'moonrise': 1643252160,
#             'moonset': 1643284620,
#             'pop': 0.38,
#             'pressure': 1033,
#             'rain': 0.42,
#             'sunrise': 1643269326,
#             'sunset': 1643302511,
#             'temp': {'day': 10.53,
#                      'eve': 8.57,
#                      'max': 10.92,
#                      'min': 2.32,
#                      'morn': 2.35,
#                      'night': 9.34},
#             'uvi': 0.9,
#             'weather': [{'description': 'light rain',
#                          'icon': '10d',
#                          'id': 500,
#                          'main': 'Rain'}],
#             'wind_deg': 279,
#             'wind_gust': 9.63,
#             'wind_speed': 4.21},
#            {'clouds': 73,
#             'dew_point': 6.55,
#             'dt': 1643371200,
#             'feels_like': {'day': 9.55,
#                            'eve': 6.65,
#                            'morn': 6.35,
#                            'night': 6.87},
#             'humidity': 78,
#             'moon_phase': 0.86,
#             'moonrise': 1643343540,
#             'moonset': 1643373300,
#             'pop': 0,
#             'pressure': 1038,
#             'sunrise': 1643355655,
#             'sunset': 1643389007,
#             'temp': {'day': 10.42,
#                      'eve': 7.52,
#                      'max': 11.34,
#                      'min': 6.34,
#                      'morn': 6.35,
#                      'night': 7.99},
#             'uvi': 1.16,
#             'weather': [{'description': 'broken clouds',
#                          'icon': '04d',
#                          'id': 803,
#                          'main': 'Clouds'}],
#             'wind_deg': 203,
#             'wind_gust': 2.97,
#             'wind_speed': 2.32},
#            {'clouds': 43,
#             'dew_point': 8.27,
#             'dt': 1643457600,
#             'feels_like': {'day': 11.07,
#                            'eve': 6.48,
#                            'morn': 6.64,
#                            'night': 6.91},
#             'humidity': 81,
#             'moon_phase': 0.89,
#             'moonrise': 1643434620,
#             'moonset': 1643462700,
#             'pop': 0,
#             'pressure': 1035,
#             'sunrise': 1643441982,
#             'sunset': 1643475504,
#             'temp': {'day': 11.73,
#                      'eve': 8.81,
#                      'max': 11.93,
#                      'min': 8.41,
#                      'morn': 8.43,
#                      'night': 9.08},
#             'uvi': 1.26,
#             'weather': [{'description': 'scattered clouds',
#                          'icon': '03d',
#                          'id': 802,
#                          'main': 'Clouds'}],
#             'wind_deg': 290,
#             'wind_gust': 10.65,
#             'wind_speed': 6.38},
#            {'clouds': 100,
#             'dew_point': 2.72,
#             'dt': 1643544000,
#             'feels_like': {'day': 7.39,
#                            'eve': 4.13,
#                            'morn': 4.06,
#                            'night': 4.8},
#             'humidity': 68,
#             'moon_phase': 0.93,
#             'moonrise': 1643525100,
#             'moonset': 1643553120,
#             'pop': 0,
#             'pressure': 1033,
#             'sunrise': 1643528306,
#             'sunset': 1643562001,
#             'temp': {'day': 8.53,
#                      'eve': 5.86,
#                      'max': 9.67,
#                      'min': 4.8,
#                      'morn': 6.62,
#                      'night': 4.8},
#             'uvi': 1.05,
#             'weather': [{'description': 'overcast clouds',
#                          'icon': '04d',
#                          'id': 804,
#                          'main': 'Clouds'}],
#             'wind_deg': 33,
#             'wind_gust': 7.22,
#             'wind_speed': 3.64},
#            {'clouds': 100,
#             'dew_point': 2.81,
#             'dt': 1643630400,
#             'feels_like': {'day': 3.63,
#                            'eve': 1.41,
#                            'morn': 3.06,
#                            'night': 1.95},
#             'humidity': 73,
#             'moon_phase': 0.97,
#             'moonrise': 1643614680,
#             'moonset': 1643644260,
#             'pop': 0.39,
#             'pressure': 1029,
#             'rain': 0.49,
#             'sunrise': 1643614629,
#             'sunset': 1643648499,
#             'temp': {'day': 7.67,
#                      'eve': 4.65,
#                      'max': 7.72,
#                      'min': 4.34,
#                      'morn': 5.99,
#                      'night': 4.43},
#             'uvi': 1.25,
#             'weather': [{'description': 'light rain',
#                          'icon': '10d',
#                          'id': 500,
#                          'main': 'Rain'}],
#             'wind_deg': 337,
#             'wind_gust': 12.93,
#             'wind_speed': 9.06},
#            {'clouds': 71,
#             'dew_point': 7.4,
#             'dt': 1643716800,
#             'feels_like': {'day': 9.76,
#                            'eve': 6.63,
#                            'morn': 4.06,
#                            'night': 7.27},
#             'humidity': 82,
#             'moon_phase': 0,
#             'moonrise': 1643703480,
#             'moonset': 1643735700,
#             'pop': 0,
#             'pressure': 1033,
#             'sunrise': 1643700950,
#             'sunset': 1643734997,
#             'temp': {'day': 10.51,
#                      'eve': 9.63,
#                      'max': 10.51,
#                      'min': 4.94,
#                      'morn': 7.05,
#                      'night': 9.85},
#             'uvi': 2,
#             'weather': [{'description': 'broken clouds',
#                          'icon': '04d',
#                          'id': 803,
#                          'main': 'Clouds'}],
#             'wind_deg': 297,
#             'wind_gust': 11.83,
#             'wind_speed': 7.9},
#            {'clouds': 88,
#             'dew_point': 8.52,
#             'dt': 1643803200,
#             'feels_like': {'day': 11.22,
#                            'eve': 7.37,
#                            'morn': 7.88,
#                            'night': 5.47},
#             'humidity': 81,
#             'moon_phase': 0.05,
#             'moonrise': 1643791620,
#             'moonset': 1643827080,
#             'pop': 0,
#             'pressure': 1032,
#             'sunrise': 1643787268,
#             'sunset': 1643821495,
#             'temp': {'day': 11.86,
#                      'eve': 9.28,
#                      'max': 12.23,
#                      'min': 7.63,
#                      'morn': 9.8,
#                      'night': 7.63},
#             'uvi': 2,
#             'weather': [{'description': 'overcast clouds',
#                          'icon': '04d',
#                          'id': 804,
#                          'main': 'Clouds'}],
#             'wind_deg': 293,
#             'wind_gust': 9.18,
#             'wind_speed': 5.4},
#            {'clouds': 94,
#             'dew_point': 7.02,
#             'dt': 1643889600,
#             'feels_like': {'day': 7.09,
#                            'eve': 9.96,
#                            'morn': 2.03,
#                            'night': 6.91},
#             'humidity': 84,
#             'moon_phase': 0.08,
#             'moonrise': 1643879340,
#             'moonset': 1643918280,
#             'pop': 0.51,
#             'pressure': 1014,
#             'rain': 0.86,
#             'sunrise': 1643873585,
#             'sunset': 1643907994,
#             'temp': {'day': 9.88,
#                      'eve': 10.6,
#                      'max': 11.52,
#                      'min': 5.33,
#                      'morn': 5.33,
#                      'night': 9.91},
#             'uvi': 2,
#             'weather': [{'description': 'light rain',
#                          'icon': '10d',
#                          'id': 500,
#                          'main': 'Rain'}],
#             'wind_deg': 230,
#             'wind_gust': 13.94,
#             'wind_speed': 7.9}],
#  'lat': 48.636,
#  'lon': -1.5115,
#  'timezone': 'Europe/Paris',
#  'timezone_offset': 3600}

# %%
example_weather.keys()
# Out:
# dict_keys(['lat', 'lon', 'timezone', 'timezone_offset', 'daily'])

# %%
len(example_weather['daily'])
# Out:
# 8

# %% [markdown]
# The api provides weather information for 8 days

# %%
# Explore the content of daily
weath_keys_all = example_weather['daily'][0].keys()
weath_keys_all
# Out:
# dict_keys(['dt', 'sunrise', 'sunset', 'moonrise', 'moonset', 'moon_phase', 'temp', 'feels_like', 'pressure', 'humidity', 'dew_point', 'wind_speed', 'wind_deg', 'wind_gust', 'weather', 'clouds', 'pop', 'rain', 'uvi'])

# %%
example_weather['daily'][0]['temp']
# Out:
# {'day': 10.53,
#  'min': 2.32,
#  'max': 10.92,
#  'night': 9.34,
#  'eve': 8.57,
#  'morn': 2.35}

# %%
example_weather['daily'][0]['feels_like']
# Out:
# {'day': 9.73, 'night': 8.49, 'eve': 6.71, 'morn': -1.04}

# %%
ex_tem_day_d0 = example_weather['daily'][0]['temp']['day']
ex_tem_night_d0 = example_weather['daily'][0]['temp']['night']
ex_feelslike_day_d0 = example_weather['daily'][0]['feels_like']['day']
ex_feelslike_night_d0 = example_weather['daily'][0]['feels_like']['night']
ex_clouds_d0 = example_weather['daily'][0]['clouds']
ex_wind_d0 = example_weather['daily'][0]['wind_speed']
ex_humidity_d0 = example_weather['daily'][0]['humidity']

# %%
print(ex_tem_day_d0)
print(ex_tem_night_d0)
print(ex_feelslike_day_d0)
print(ex_feelslike_night_d0)
print(ex_clouds_d0)
print(ex_wind_d0)
print(ex_humidity_d0)
# Out:
# 10.53
# 9.34
# 9.73
# 8.49
# 89
# 4.21
# 80

# %%
# Get weather data we choosed to keep for all cities 
df_weather = []
days = 8

for i in range(df.shape[0]):
    for j in range(days):
        r = requests.get("https://api.openweathermap.org/data/2.5/onecall?lat={}&lon={}&exclude=hourly,current,minutely&appid=93dd497abfa8c0ecdc1920ba1bacd20e&units=metric"
                         .format(df.latitude[i],df.longitude[i])).json()
        city = df.city[i]
        lat = df.latitude[i]
        lon = df.longitude[i]
        day = j
        d = r['daily']
        date = datetime.fromtimestamp(d[j]['dt']).strftime('%d/%m/%Y')
        tem_day = d[j]['temp']['day']
        tem_night = d[j]['temp']['night']
        feelslike_day = d[j]['feels_like']['day']
        feelslike_night = d[j]['feels_like']['night']
        clouds = d[j]['clouds']
        wind = d[j]['wind_speed']
        humidity = d[j]['humidity']
        df_weather.append([city, lat, lon, day, date, tem_day, tem_night, feelslike_day, feelslike_night, clouds, wind, humidity])

# %%
# Create a dataframe with the weather data
cols = ['city','latitude', 'longitude', 'day', 'date', 'temp_day', 'temp_night', 'feels_like_day', 'feels_like_night', 'clouds', 'wind_speed', 'humidity']
df_weather_days = pd.DataFrame(df_weather, columns=cols)
pd.set_option('display.max_rows', None)
df_weather_days.head(10)
# Out:
#                 city  latitude  longitude  day        date  temp_day  \
# 0  Mont Saint Michel   48.6360    -1.5115    0  27/01/2022     10.53
# 1  Mont Saint Michel   48.6360    -1.5115    1  28/01/2022     10.42
# 2  Mont Saint Michel   48.6360    -1.5115    2  29/01/2022     11.73
# 3  Mont Saint Michel   48.6360    -1.5115    3  30/01/2022      8.53
# 4  Mont Saint Michel   48.6360    -1.5115    4  31/01/2022      7.67
# 5  Mont Saint Michel   48.6360    -1.5115    5  01/02/2022     10.51
# 6  Mont Saint Michel   48.6360    -1.5115    6  02/02/2022     11.86
# 7  Mont Saint Michel   48.6360    -1.5115    7  03/02/2022      9.88
# 8            St Malo   48.6495    -2.0260    0  27/01/2022     10.39
# 9            St Malo   48.6495    -2.0260    1  28/01/2022     10.42
#
#    temp_night  feels_like_day  feels_like_night  clouds  wind_speed  humidity
# 0        9.34            9.73              8.49      89        4.21        80
# 1        7.99            9.55              6.87      73        2.32        78
# 2        9.08           11.07              6.91      43        6.38        81
# 3        4.80            7.39              4.80     100        3.64        68
# 4        4.43            3.63              1.95     100        9.06        73
# 5        9.85            9.76              7.27      71        7.90        82
# 6        7.63           11.22              5.47      88        5.40        81
# 7        9.91            7.09              6.91      94        7.90        84
# 8        9.70            9.50              8.03      92        6.00        77
# 9        8.95            9.58              6.98      73        3.47        79

# %%
df_weather_days['city'].nunique()
# Out:
# 35

# %%
# Store weather data for all days in a csv
df_weather_days.to_csv('src/weather_days.csv')

# %%
df_weather_days = pd.read_csv('src/weather_days.csv')

# %%
# Define a function that gives a list of 5 top cities according to a specific criteria and how the user want it to be sorted
def top_cities_names(nb_cities, criteria, ascending):
    res = df_weather_days.groupby('city')[criteria].mean().sort_values(ascending=ascending).reset_index()[0:nb_cities]['city'].values
    return res

# %%
top_cities_names(5,'temp_day',False)
# Out:
# array(['Collioure', 'Nimes', 'Aigues Mortes', 'Cassis',
#        'Saintes Maries de la mer'], dtype=object)

# %%
# Define a dataframe with the average weather mesures on 8 days
df_weather_avg = df_weather_days.groupby('city').mean()
df_weather_avg.head()
# Out:
#                  Unnamed: 0  latitude  longitude  day  temp_day  temp_night  \
# city
# Aigues Mortes         203.5   43.5658     4.1913  3.5  12.22250     9.10250
# Aix en Provence       171.5   43.5298     5.4475  3.5  11.00750     7.07000
# Amiens                 51.5   49.8942     2.2957  3.5   9.07875     6.81375
# Annecy                115.5   45.8992     6.1289  3.5   7.60500     3.01250
# Ariege                235.5   42.9455     1.4066  3.5   5.68000     0.25000
#
#                  feels_like_day  feels_like_night  clouds  wind_speed  \
# city
# Aigues Mortes          10.86375           6.87750  18.000     7.31750
# Aix en Provence         9.55250           5.86500  17.375     3.71875
# Amiens                  7.35250           4.92875  83.625     6.93500
# Annecy                  6.67500           2.56875  58.750     2.14500
# Ariege                  4.25125          -1.72750  36.000     2.59625
#
#                  humidity
# city
# Aigues Mortes      51.500
# Aix en Provence    48.750
# Amiens             80.500
# Annecy             69.875
# Ariege             58.000

# %%
# Drop useless columns
df_weather_avg.drop(['Unnamed: 0', 'day'], inplace=True, axis=1)

# %%
df_weather_avg.head()
# Out:
#                  latitude  longitude  temp_day  temp_night  feels_like_day  \
# city
# Aigues Mortes     43.5658     4.1913  12.22250     9.10250        10.86375
# Aix en Provence   43.5298     5.4475  11.00750     7.07000         9.55250
# Amiens            49.8942     2.2957   9.07875     6.81375         7.35250
# Annecy            45.8992     6.1289   7.60500     3.01250         6.67500
# Ariege            42.9455     1.4066   5.68000     0.25000         4.25125
#
#                  feels_like_night  clouds  wind_speed  humidity
# city
# Aigues Mortes             6.87750  18.000     7.31750    51.500
# Aix en Provence           5.86500  17.375     3.71875    48.750
# Amiens                    4.92875  83.625     6.93500    80.500
# Annecy                    2.56875  58.750     2.14500    69.875
# Ariege                   -1.72750  36.000     2.59625    58.000

# %%
# Store in a csv the weather average data
df_weather_avg.to_csv('src/weather.csv')

# %%
# Define a function that returns a sorted dataset according to a column with the average of weather measures on the 8 days
def df_sorted_cities(df, column, ascending):
    res = df.groupby('city').mean().sort_values(column, ascending=ascending).reset_index()
    return res

# %%
df_sorted_cities(df_weather_days, 'temp_day', False).head()
# Out:
#                        city  Unnamed: 0  latitude  longitude  day  temp_day  \
# 0                 Collioure       219.5   42.5251     3.0832  3.5  14.52750
# 1                     Nimes       195.5   43.8374     4.3601  3.5  12.32375
# 2             Aigues Mortes       203.5   43.5658     4.1913  3.5  12.22250
# 3                    Cassis       155.5   43.2140     5.5396  3.5  12.15875
# 4  Saintes Maries de la mer       211.5   43.4523     4.4287  3.5  12.09000
#
#    temp_night  feels_like_day  feels_like_night  clouds  wind_speed  humidity
# 0    10.31500        13.24750           8.38500  15.000     8.76750    46.375
# 1     7.42500        10.63750           4.82875  18.625     7.79375    47.125
# 2     9.10250        10.86375           6.87750  18.000     7.31750    51.500
# 3    10.04000        10.80500           8.24750  21.375     6.30750    52.625
# 4     9.58625        10.59750           6.88375  24.125    10.47625    53.375

# %%
#  Visualize all cities average temperature
cities_temp = df_sorted_cities(df_weather_avg,'temp_day',False)
fig1 = px.scatter_mapbox(cities_temp, lat="latitude", lon="longitude", color="temp_day",hover_name="city", size="temp_day",
                        mapbox_style="carto-positron", zoom=5)
fig1.update_layout(title='Cities temperature')
fig1.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_92.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
# Define some variables for the plo loop
weather_cols_sens = [('temp_day','des'), 
                    ('temp_night','des'), 
                    ('feels_like_day','des'), 
                    ('feels_like_night','des'), 
                    ('clouds','asc'), 
                    ('wind_speed','asc'), 
                    ('humidity','asc')]
dict_titles = {
    'temp_day':'average 8 days temperature during the day' , 
    'temp_night':'average 8 days temperature during the night', 
    'feels_like_day':'average 8 days felt temperature during the day', 
    'feels_like_night': 'average 8 days felt temperature during the night', 
    'clouds': 'average 8 days clouds', 
    'wind_speed': 'average 8 days wind speed', 
    'humidity': 'average 8 days humidity'    
}

dict_sens = {
    'asc' : True,
    'des' : False
}

# %%
# Visualise top 5 cities according to different weather columns
for col, sort in weather_cols_sens:
    fig2 = px.scatter_mapbox(df_sorted_cities(df_weather_avg,col,dict_sens[sort])[0:5], lat="latitude", lon="longitude", color=col,hover_name="city", size=col,
                        mapbox_style="carto-positron", zoom=5)
    fig2.update_layout(title = 'Top 5 cities according to {}'.format(dict_titles[col]))
    fig2.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_108.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_108.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_108.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_108.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_108.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_108.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_108.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ## Part III : scraping booking.com

# %%
# test urls that allow selecting only hotels in desending rating order for all cities
list_url_essai = []
for i in range (0, len(cities)):
    list_url_essai.append("https://www.booking.com/searchresults.fr.html?label=gen173nr-1DCAEoggI46AdIM1gEaE2IAQGYAQ24ARfIAQzYAQPoAQGIAgGoAgO4ApSdyo8GwAIB0gIkMDcyYTY0N2YtMWQzYS00ZWE1LTlhYTYtYWI0MThkMTM1ZTcz2AIE4AIB&sid=1af4ef95ff0245766f5bd84859ae7b29&aid=304142&lang=fr&sb_lp=1&error_url=https%3A%2F%2Fwww.booking.com%2Findex.fr.html%3Flabel%3Dgen173nr-1DCAEoggI46AdIM1gEaE2IAQGYAQ24ARfIAQzYAQPoAQGIAgGoAgO4ApSdyo8GwAIB0gIkMDcyYTY0N2YtMWQzYS00ZWE1LTlhYTYtYWI0MThkMTM1ZTcz2AIE4AIB%3Bsid%3D1af4ef95ff0245766f5bd84859ae7b29%3Bsb_price_type%3Dtotal%26%3B&ss={}&nflt=ht_id%3D204&shw_aparth=0&order=bayesian_review_score"
                .format(cities[i].replace(' ','+')))
list_url_essai[0]
# Out:
# 'https://www.booking.com/searchresults.fr.html?label=gen173nr-1DCAEoggI46AdIM1gEaE2IAQGYAQ24ARfIAQzYAQPoAQGIAgGoAgO4ApSdyo8GwAIB0gIkMDcyYTY0N2YtMWQzYS00ZWE1LTlhYTYtYWI0MThkMTM1ZTcz2AIE4AIB&sid=1af4ef95ff0245766f5bd84859ae7b29&aid=304142&lang=fr&sb_lp=1&error_url=https%3A%2F%2Fwww.booking.com%2Findex.fr.html%3Flabel%3Dgen173nr-1DCAEoggI46AdIM1gEaE2IAQGYAQ24ARfIAQzYAQPoAQGIAgGoAgO4ApSdyo8GwAIB0gIkMDcyYTY0N2YtMWQzYS00ZWE1LTlhYTYtYWI0MThkMTM1ZTcz2AIE4AIB%3Bsid%3D1af4ef95ff0245766f5bd84859ae7b29%3Bsb_price_type%3Dtotal%26%3B&ss=Mont+Saint+Michel&nflt=ht_id%3D204&shw_aparth=0&order=bayesian_review_score'

# %%
# Booking scraping
class BookingSpider(scrapy.Spider):
    
    name = "booking"      
    city_idx = 0
    list_url = []
    for i in range (0, len(cities)):
        list_url.append("https://www.booking.com/searchresults.fr.html?label=gen173nr-1DCAEoggI46AdIM1gEaE2IAQGYAQ24ARfIAQzYAQPoAQGIAgGoAgO4ApSdyo8GwAIB0gIkMDcyYTY0N2YtMWQzYS00ZWE1LTlhYTYtYWI0MThkMTM1ZTcz2AIE4AIB&sid=1af4ef95ff0245766f5bd84859ae7b29&aid=304142&lang=fr&sb_lp=1&error_url=https%3A%2F%2Fwww.booking.com%2Findex.fr.html%3Flabel%3Dgen173nr-1DCAEoggI46AdIM1gEaE2IAQGYAQ24ARfIAQzYAQPoAQGIAgGoAgO4ApSdyo8GwAIB0gIkMDcyYTY0N2YtMWQzYS00ZWE1LTlhYTYtYWI0MThkMTM1ZTcz2AIE4AIB%3Bsid%3D1af4ef95ff0245766f5bd84859ae7b29%3Bsb_price_type%3Dtotal%26%3B&ss={}&nflt=ht_id%3D204&shw_aparth=0&order=bayesian_review_score"
                .format(cities[i].replace(' ','+')))

    start_urls = list_url                
    
    def parse(self, response):
        hotels = response.css('div._fe1927d9e._0811a1b54._a8a1be610._022ee35ec.b9c27d6646.fb3c4512b4.fc21746a73')
        for hotel in hotels:
            hotel_url = hotel.css('a::attr(href)').get()
            hotel_name = hotel.css('div.fde444d7ef._c445487e2::text').get()
            yield scrapy.Request(
                    hotel_url, 
                    callback=self.scrap_hotel,
                    meta={'city' : cities[self.city_idx],
                         'hotel_url' : hotel_url,
                         'hotel_name' : hotel_name }
                    )
        self.city_idx += 1
    def scrap_hotel(self, response):
        return {
                'city' : response.meta.get('city'),
                'hotel_name': response.meta.get('hotel_name'),
                'hotel_ranking': response.css('div._9c5f726ff.bd528f9ea6::text').get(),
                'hotel_description': ''.join(response.css('div#property_description_content p::text').getall()),
                'hotel_url' : response.meta.get('hotel_url'),
                'hotel_lat':response.css('a#hotel_header').attrib['data-atlas-latlng'].split(",")[0],
                'hotel_lon':response.css('a#hotel_header').attrib['data-atlas-latlng'].split(",")[1]
                }

# %%
# Name of the file where the results will be saved
filename = "top_hotels.json"

# If file already exists, delete it before crawling
if filename in os.listdir('src/'):
        os.remove('src/' + filename)

# Declare a new CrawlerProcess
process = CrawlerProcess(settings = {
    'USER_AGENT': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:96.0) Gecko/20100101 Firefox/96.0', #=> Simulates a browser on an OS
    'LOG_LEVEL': logging.INFO, # => Minimal Level of Log 
    "FEEDS": {
        'src/' + filename : {"format": "json"}, # => Where the file will be stored
    },
    "AUTOTHROTTLE_ENABLED": True
})

# Start the crawling
process.crawl(BookingSpider)
process.start()
# Out:
# 2022-01-27 12:45:40 [scrapy.utils.log] INFO: Scrapy 2.5.1 started (bot: scrapybot)
# 2022-01-27 12:45:40 [scrapy.utils.log] INFO: Versions: lxml 4.7.1.0, libxml2 2.9.12, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 21.7.0, Python 3.8.6 | packaged by conda-forge | (default, Oct  7 2020, 19:08:05) - [GCC 7.5.0], pyOpenSSL 19.1.0 (OpenSSL 1.1.1h  22 Sep 2020), cryptography 3.1.1, Platform Linux-5.4.129+-x86_64-with-glibc2.10
# 2022-01-27 12:45:40 [scrapy.crawler] INFO: Overridden settings:
# {'AUTOTHROTTLE_ENABLED': True,
#  'LOG_LEVEL': 20,
#  'USER_AGENT': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:96.0) '
#                'Gecko/20100101 Firefox/96.0'}
# 2022-01-27 12:45:40 [scrapy.extensions.telnet] INFO: Telnet Password: 8c8ce0bd750bd326
# 2022-01-27 12:45:40 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats',
#  'scrapy.extensions.throttle.AutoThrottle']
# 2022-01-27 12:45:40 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2022-01-27 12:45:40 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2022-01-27 12:45:40 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2022-01-27 12:45:40 [scrapy.core.engine] INFO: Spider opened
# 2022-01-27 12:45:40 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2022-01-27 12:45:40 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2022-01-27 12:46:40 [scrapy.extensions.logstats] INFO: Crawled 54 pages (at 54 pages/min), scraped 37 items (at 37 items/min)
# 2022-01-27 12:47:40 [scrapy.extensions.logstats] INFO: Crawled 110 pages (at 56 pages/min), scraped 93 items (at 56 items/min)
# 2022-01-27 12:48:40 [scrapy.extensions.logstats] INFO: Crawled 168 pages (at 58 pages/min), scraped 151 items (at 58 items/min)
# 2022-01-27 12:49:40 [scrapy.extensions.logstats] INFO: Crawled 222 pages (at 54 pages/min), scraped 205 items (at 54 items/min)
# 2022-01-27 12:50:40 [scrapy.extensions.logstats] INFO: Crawled 273 pages (at 51 pages/min), scraped 256 items (at 51 items/min)
# 2022-01-27 12:51:40 [scrapy.extensions.logstats] INFO: Crawled 325 pages (at 52 pages/min), scraped 308 items (at 52 items/min)
# 2022-01-27 12:52:40 [scrapy.extensions.logstats] INFO: Crawled 376 pages (at 51 pages/min), scraped 358 items (at 50 items/min)
# 2022-01-27 12:53:40 [scrapy.extensions.logstats] INFO: Crawled 430 pages (at 54 pages/min), scraped 413 items (at 55 items/min)
# 2022-01-27 12:54:40 [scrapy.extensions.logstats] INFO: Crawled 502 pages (at 72 pages/min), scraped 468 items (at 55 items/min)
# 2022-01-27 12:55:40 [scrapy.extensions.logstats] INFO: Crawled 560 pages (at 58 pages/min), scraped 525 items (at 57 items/min)
# 2022-01-27 12:56:40 [scrapy.extensions.logstats] INFO: Crawled 612 pages (at 52 pages/min), scraped 578 items (at 53 items/min)
# 2022-01-27 12:57:40 [scrapy.extensions.logstats] INFO: Crawled 668 pages (at 56 pages/min), scraped 634 items (at 56 items/min)
# 2022-01-27 12:58:40 [scrapy.extensions.logstats] INFO: Crawled 725 pages (at 57 pages/min), scraped 690 items (at 56 items/min)
# 2022-01-27 12:59:40 [scrapy.extensions.logstats] INFO: Crawled 780 pages (at 55 pages/min), scraped 745 items (at 55 items/min)
# 2022-01-27 13:00:40 [scrapy.extensions.logstats] INFO: Crawled 835 pages (at 55 pages/min), scraped 801 items (at 56 items/min)
# 2022-01-27 13:01:40 [scrapy.extensions.logstats] INFO: Crawled 891 pages (at 56 pages/min), scraped 856 items (at 55 items/min)
# 2022-01-27 13:02:03 [scrapy.core.engine] INFO: Closing spider (finished)
# 2022-01-27 13:02:03 [scrapy.extensions.feedexport] INFO: Stored json feed (875 items) in: src/top_hotels.json
# 2022-01-27 13:02:03 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 1570629,
#  'downloader/request_count': 910,
#  'downloader/request_method_count/GET': 910,
#  'downloader/response_bytes': 202891722,
#  'downloader/response_count': 910,
#  'downloader/response_status_count/200': 910,
#  'elapsed_time_seconds': 983.022241,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2022, 1, 27, 13, 2, 3, 626727),
#  'httpcompression/response_bytes': 1230128771,
#  'httpcompression/response_count': 910,
#  'item_scraped_count': 875,
#  'log_count/INFO': 27,
#  'memusage/max': 582770688,
#  'memusage/startup': 147894272,
#  'request_depth_max': 1,
#  'response_received_count': 910,
#  'scheduler/dequeued': 910,
#  'scheduler/dequeued/memory': 910,
#  'scheduler/enqueued': 910,
#  'scheduler/enqueued/memory': 910,
#  'start_time': datetime.datetime(2022, 1, 27, 12, 45, 40, 604486)}
# 2022-01-27 13:02:03 [scrapy.core.engine] INFO: Spider closed (finished)

# %%
# Import the scraping results from the .json file
df_hotels = pd.read_json('src/top_hotels.json')

# %%
df_hotels.head()
# Out:
#                 city                 hotel_name hotel_ranking  \
# 0  Mont Saint Michel                 Le Lithana           7,3
# 1            St Malo  Escale Oceania Saint Malo           8,2
# 2           Le Havre             Hôtel Le Green           4,2
# 3             Bayeux         Hôtel De La Marine           8,1
# 4              Rouen                     Astrid           6,5
#
#                                    hotel_description  \
# 0  Vous pouvez bénéficier d'une réduction Genius ...
# 1  Vous pouvez bénéficier d'une réduction Genius ...
# 2  L'Hôtel Le Green est situé dans le centre du H...
# 3  Face à la mer et au célèbre musée du Débarquem...
# 4  Cet hôtel moderne est situé en face de la gare...
#
#                                            hotel_url  hotel_lat  hotel_lon
# 0  https://www.booking.com/hotel/fr/le-lithana.fr...  48.554097  -1.500629
# 1  https://www.booking.com/hotel/fr/mascottesaint...  48.654280  -2.008838
# 2  https://www.booking.com/hotel/fr/le-green.fr.h...  49.492303   0.122933
# 3  https://www.booking.com/hotel/fr/de-la-marine....  49.340483  -0.623109
# 4  https://www.booking.com/hotel/fr/hotelastrid_r...  49.448306   1.093814

# %%
#Data cleaning
df_hotels['hotel_name'] = df_hotels['hotel_name'].str.replace(r'NOCNOC - ', '')
df_hotels['hotel_name'] = df_hotels['hotel_name'].str.replace(r'par NOCNOC', '')
df_hotels['hotel_description'] = df_hotels['hotel_description'].str.replace(r'\xa0', '')
df_hotels['hotel_description'] = df_hotels['hotel_description'].str.replace(r' - ', ' ')
df_hotels['hotel_description'] = df_hotels['hotel_description'].str.replace(r'NOCNOC', '')
df_hotels['hotel_description'] = df_hotels['hotel_description'].str.replace(r'par NOCNOC', '')
df_hotels['hotel_description'] = df_hotels['hotel_description'].str.replace(r'.', '. ')
df_hotels['hotel_description'] = df_hotels['hotel_description'].str.replace(r'  ', ' ')
df_hotels['hotel_ranking'] = df_hotels['hotel_ranking'].str.replace(r',', '.')
df_hotels['hotel_ranking'] = df_hotels['hotel_ranking'].astype(float)

# %%
df_hotels.head()
# Out:
#                 city                 hotel_name  hotel_ranking  \
# 0  Mont Saint Michel                 Le Lithana            7.3
# 1            St Malo  Escale Oceania Saint Malo            8.2
# 2           Le Havre             Hôtel Le Green            4.2
# 3             Bayeux         Hôtel De La Marine            8.1
# 4              Rouen                     Astrid            6.5
#
#                                    hotel_description  \
# 0  Vous pouvez bénéficier d'une réduction Genius ...
# 1  Vous pouvez bénéficier d'une réduction Genius ...
# 2  L'Hôtel Le Green est situé dans le centre du H...
# 3  Face à la mer et au célèbre musée du Débarquem...
# 4  Cet hôtel moderne est situé en face de la gare...
#
#                                            hotel_url  hotel_lat  hotel_lon
# 0  https://www.booking.com/hotel/fr/le-lithana.fr...  48.554097  -1.500629
# 1  https://www.booking.com/hotel/fr/mascottesaint...  48.654280  -2.008838
# 2  https://www.booking.com/hotel/fr/le-green.fr.h...  49.492303   0.122933
# 3  https://www.booking.com/hotel/fr/de-la-marine....  49.340483  -0.623109
# 4  https://www.booking.com/hotel/fr/hotelastrid_r...  49.448306   1.093814

# %%
# Merge weather and hotels dataframes
df_kayak = df_hotels.merge(df_weather_avg, on=['city'])

# %%
df_kayak.columns
# Out:
# Index(['city', 'hotel_name', 'hotel_ranking', 'hotel_description', 'hotel_url',
#        'hotel_lat', 'hotel_lon', 'latitude', 'longitude', 'temp_day',
#        'temp_night', 'feels_like_day', 'feels_like_night', 'clouds',
#        'wind_speed', 'humidity'],
#       dtype='object')

# %%
# Drop useless columns
df_kayak.drop(['latitude', 'longitude'], inplace=True, axis=1)

# %%
df_kayak.head()
# Out:
#                 city                                         hotel_name  \
# 0  Mont Saint Michel                                         Le Lithana
# 1  Mont Saint Michel                                        Le Beauvoir
# 2  Mont Saint Michel                                 Hôtel Ariane & SPA
# 3  Mont Saint Michel  Manoir de la Roche Torin, The Originals Relais...
# 4  Mont Saint Michel  The Originals Boutique, Hôtel Les Quatre Salin...
#
#    hotel_ranking                                  hotel_description  \
# 0            7.3  Vous pouvez bénéficier d'une réduction Genius ...
# 1            7.7  Vous pouvez bénéficier d'une réduction Genius ...
# 2            7.6  Ce charmant hôtel est situé à la frontière ent...
# 3            7.7  Vous pouvez bénéficier d'une réduction Genius ...
# 4            7.9  Vous pouvez bénéficier d'une réduction Genius ...
#
#                                            hotel_url  hotel_lat  hotel_lon  \
# 0  https://www.booking.com/hotel/fr/le-lithana.fr...  48.554097  -1.500629
# 1  https://www.booking.com/hotel/fr/le-beauvoir-b...  48.597713  -1.513098
# 2  https://www.booking.com/hotel/fr/ariane-pontor...  48.552403  -1.507123
# 3  https://www.booking.com/hotel/fr/le-manoir-de-...  48.637273  -1.425062
# 4  https://www.booking.com/hotel/fr/lessalines.fr...  48.596404  -1.589203
#
#    temp_day  temp_night  feels_like_day  feels_like_night  clouds  wind_speed  \
# 0  10.14125     7.87875            8.68           6.08375   82.25     5.85125
# 1  10.14125     7.87875            8.68           6.08375   82.25     5.85125
# 2  10.14125     7.87875            8.68           6.08375   82.25     5.85125
# 3  10.14125     7.87875            8.68           6.08375   82.25     5.85125
# 4  10.14125     7.87875            8.68           6.08375   82.25     5.85125
#
#    humidity
# 0    78.375
# 1    78.375
# 2    78.375
# 3    78.375
# 4    78.375

# %%
# Export the dataframe to a csv
df_kayak.to_csv('src/kayak.csv')

# %%
# List of top 5 cities
top_cities_names(5,'temp_day',False)
# Out:
# array(['Collioure', 'Nimes', 'Aigues Mortes', 'Cassis',
#        'Saintes Maries de la mer'], dtype=object)

# %%
# Loop on top five cities to plot the 20 hight rated hotels in each city
for city in top_cities_names(5,'temp_day',False):
    data = df_kayak.loc[df_kayak['city']==city].sort_values('hotel_ranking', ascending=False)[0:20]
    fig = px.scatter_mapbox(data, 
                            lat="hotel_lat", 
                            lon="hotel_lon", 
                            color="hotel_ranking",
                            hover_name="hotel_name", 
                            mapbox_style="carto-positron", 
                            zoom=5)
    fig.update_layout(title= 'Top 20 hotels in {}'.format(city))
    fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_69.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_69.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_69.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_69.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_69.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
